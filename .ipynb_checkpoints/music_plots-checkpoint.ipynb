# %% [markdown]
# # Exploring Music Data with Matplotlib

# %% [markdown]
# These Python scripts use data downloaded from the Last.fm and Spotify databases with the script 'musicfetch.py'.
# The data consists of a list of dictionaries with features about the top 100 tracks played by the user. We begin by importing this data using the 'JSON' module in Python.

# %%
import json
import os.path
import numpy as np
import matplotlib.pyplot as plt

# To display plot inline in an IPython notebook
# %matplotlib inline


# Check if JSON data file exists in folder path and read from it
if os.path.isfile("my_top_tracks.txt"):
    json_data = open("my_top_tracks.txt").read()
    my_top_tracks = json.loads(json_data)
    
else:
    print("Please run musicfetch.py to generate data.")

# %% [markdown]
# ## Making a Simple Bar Chart
#
# Using matplotlib, we create the first plot: a simple horizontal bar chart which displays playcounts for the top tracks. The data for 'top_tracks' and 'playcount' are pulled from the dictionaries and arranged in simple lists through iteration.
#
# The script also asks for user input on the number of tracks to be plotted, the number is used to slice the list containing the top tracks, and then it is also used to determine the height of the figure, so that it scales in proportion to the number of bars to be plotted.

# %%
number = int(input("How many top tracks? "))

# Setup Figure
fig = plt.figure(figsize=(10, number / 2))
# Create an axis with a 1x1 grid
ax = fig.add_subplot(1, 1, 1)

# Data:
top_tracks = [track['title'] + " - " +track['artist'] for track in my_top_tracks[:number]]
print("\nTracks:", top_tracks)
playcount = [track['user_playcount'] for track in my_top_tracks[:number]]
print("\nPlaycounts:", playcount)

# The position in y for the bars and labels
y_pos = np.arange(len(top_tracks))
# Width of the bars
width = 1

# Create a horizontal bar chart
bch = ax.barh(y_pos + width, playcount, width, color='red', align='center')
# Set range of the y axis
ax.set_ylim([0, number + width])
# Set ticks and labels
plt.yticks(y_pos + width, top_tracks)
plt.xlabel('Playcount')
plt.title('My Most Listened-to Tracks:')

# Invert y-axis so the track with highest playcounts is on top
plt.gca().invert_yaxis()

plt.show()
# Out:
# How many top tracks? 10
#
# Tracks: ['Almost Lover - A Fine Frenzy', 'Breedless - Ego Likeness', 'Energize Me - After Forever', '100 Other Lovers - DeVotchKa', 'The Bed Song - Amanda Palmer & The Grand Theft Orchestra', 'Bad Man - Vermillion Lies', 'Bluebird - The Horse Thieves', 'Song For Samael - Ego Likeness', 'South - Ego Likeness', 'Treacherous Thing - Ego Likeness']
#
# Playcounts: [73, 58, 50, 48, 48, 46, 46, 46, 45, 44]

# %% [markdown]
# ## A Scatter Plot with Fancy Tooltips
#
# Here, a similar method is used to create a scatter plot of some of the audio features of the tracks in the data file.
# A description of these audio features and their meaning can be found in: http://developer.echonest.com/acoustic-attributes.html
#
# In addition to allowing user input on the number of tracks plotted, the resulting figure also allows some interactivity by using the MPLD3 module. MPLD3 adds Javascript bindings to the matplotlib graphics, which allows the user to interact with it in the browser. Here, we use it to add tooltips to the scatterplot, displaying the name of the track represented by each point when the user hovers over it with the mouse.

# %%
import mpld3

number = int(input("How many top tracks? "))

# Setup Figure
fig = plt.figure(figsize=(8, 8))
# Create an axis with a 1x1 grid
ax = fig.add_subplot(1, 1, 1)

# Data:
# Using the .get() method avoids a key error if key is not found
energy = [track.get('energy') for track in my_top_tracks[:number]]
valence = [track.get('valence') for track in my_top_tracks[:number]]

# Datapoint features:
# create a color gradient based on the values
colors = valence
# Area of the circles will be proportional to playcount
playcount = [int(track['user_playcount']) * 2 for track in my_top_tracks[:number]]
area = playcount

# Create plot
scatterplt = ax.scatter(energy, valence, s=area, c=colors, alpha=0.5)
#ax.grid(color='#b2b2b2', linestyle='dotted')

# Labels
plt.ylabel('valence')
plt.xlabel('energy')
plt.title('Audio Features')
ax.xaxis.labelpad=20
ax.yaxis.labelpad=20

# Display tooltips using mpld3
tracks = [track['title'] + " - " +track['artist'] for track in my_top_tracks[:number]]
tooltip = mpld3.plugins.PointHTMLTooltip(scatterplt, labels=tracks, voffset=-20)
mpld3.plugins.connect(fig, tooltip)

mpld3.display()
# Out:
# How many top tracks? 100
# <style>
#
# </style>
#
# <div id="fig_el147491404893426449123150812059"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("htmltooltip", HtmlTooltipPlugin);
#     HtmlTooltipPlugin.prototype = Object.create(mpld3.Plugin.prototype);
#     HtmlTooltipPlugin.prototype.constructor = HtmlTooltipPlugin;
#     HtmlTooltipPlugin.prototype.requiredProps = ["id"];
#     HtmlTooltipPlugin.prototype.defaultProps = {labels:null, hoffset:0, voffset:10};
#     function HtmlTooltipPlugin(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     HtmlTooltipPlugin.prototype.draw = function(){
#        var obj = mpld3.get_element(this.props.id);
#        var labels = this.props.labels;
#        var tooltip = d3.select("body").append("div")
#                     .attr("class", "mpld3-tooltip")
#                     .style("position", "absolute")
#                     .style("z-index", "10")
#                     .style("visibility", "hidden");
#
#        obj.elements()
#            .on("mouseover", function(d, i){
#                               tooltip.html(labels[i])
#                                      .style("visibility", "visible");})
#            .on("mousemove", function(d, i){
#                     tooltip
#                       .style("top", d3.event.pageY + this.props.voffset + "px")
#                       .style("left",d3.event.pageX + this.props.hoffset + "px");
#                  }.bind(this))
#            .on("mouseout",  function(d, i){
#                            tooltip.style("visibility", "hidden");});
#     };
#
#        mpld3.draw_figure("fig_el147491404893426449123150812059", {"height": 640.0, "plugins": [{"type": "reset"}, {"button": true, "enabled": false, "type": "zoom"}, {"button": true, "enabled": false, "type": "boxzoom"}, {"id": "el14749140489336011464", "voffset": -20, "labels": ["Almost Lover - A Fine Frenzy", "Breedless - Ego Likeness", "Energize Me - After Forever", "100 Other Lovers - DeVotchKa", "The Bed Song - Amanda Palmer & The Grand Theft Orchestra", "Bad Man - Vermillion Lies", "Bluebird - The Horse Thieves", "Song For Samael - Ego Likeness", "South - Ego Likeness", "Treacherous Thing - Ego Likeness", "The Vice - Bitter Ruin", "Inferno - Ego Likeness", "Kev\u00e4t - Tavaramarkkinat", "The Point of It All - Amanda Palmer", "I Should Fly - Vermillion Lies", "Bad Wine and Lemon Cake (with The Jane Austen Argument) - Amanda Palmer", "Delilah - The Dresden Dolls", "S\u00e9ance - Ego Likeness", "The Devils In The Chemicals - Ego Likeness", "The Kill - The Dresden Dolls", "Guitar Hero - Amanda Palmer", "Soldier - Bitter Ruin", "Jerusalem - The Indelicates", "You And Your Sister - This Mortal Coil", "Beautiful Freak - Eels", "Labios Compartidos - Man\u00e1", "Missed Me - The Dresden Dolls", "Shores Of California - The Dresden Dolls", "City Lights Cry - Armistice", "Gray Or Blue - Jaymay", "I Like Birds - Eels", "If You Go Away - Emil\u00edana Torrini", "Mandy Goes to Med School - The Dresden Dolls", "Vuorien taa - Indica", "Frozen - Delain", "I Like The Way This Is Going - Eels", "I Will